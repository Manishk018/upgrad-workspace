# %%
import numpy as np
import pandas as pd

df=pd.read_csv('cars.csv',sep=',',header=None, index_col=0)
df1=df.iloc[1]
print(df1)
# Out:
# 1          AUS
# 2    Australia
# 3        731.0
# 4         True
# Name: ASPAC, dtype: object

# %%
df.index
# Out:
# Index(['USCA', 'ASPAC', 'ASPAC', 'ASPAC', 'ASPAC', 'LATAM', 'AFR', 'EUR'], dtype='object', name=0)

# %%
df.index.name='Region specific'

# %%
'word'.upper().startswith('W')
# Out:
# True

# %%
data=pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv', sep='|',header=0, index_col=0)
data.index.name='S.No.'
data.columns=['Name','Subject','Maximum Marks', 'Marks Obtained', 'Percentage']

print(data)
# Out:
#           Name      Subject  Maximum Marks  Marks Obtained  Percentage
# S.No.
# 2       Mahima      English             40              33          83
# 3        Vikas  Mathematics             50              42          84
# 4      Abhinav      English             40              31          78
# 5       Mahima      Science             50              40          80
# 6       Akshay      Science             50              49          98
# 7      Abhinav  Mathematics             50              47          94
# 8        Vikas      Science             50              40          80
# 9      Abhinav      Science             50              47          94
# 10       Vikas      English             40              39          98
# 11      Akshay      English             40              35          88
# 12      Mahima  Mathematics             50              43          86

# %%
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv')

# %%
print(df.head(5))
print(df.tail(5))
# Out:
#       ID Department     Office  Rating
# 0  U2F26    Finance  New Delhi     3.4
# 1  U2M61  Marketing  New Delhi     3.9
# 2  U1S15      Sales  New Delhi     2.8
# 3  U1H87         HR     Mumbai     2.1
# 4  U1S51      Sales  New Delhi     4.6
#         ID Department     Office  Rating
# 528  U3S44      Sales  New Delhi     4.8
# 529  U2M11  Marketing  Bangalore     2.5
# 530  U3F53    Finance  Bangalore     3.2
# 531  U3S46      Sales  Bangalore     2.9
# 532  U3S28      Sales  New Delhi     2.9

# %%
df.describe()
# Out:
#            Rating
# count  524.000000
# mean     3.550191
# std      0.850430
# min      2.100000
# 25%      2.800000
# 50%      3.500000
# 75%      4.300000
# max      5.000000

# %%
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
# print(df)
print(df.head(5))
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df.iloc[[3],[0,1,10]]
# Out:
#    X  Y  wind
# 3  8  6   4.0

# %%
df[::2]
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0

# %%
df[['X','Y']]
# Out:
#      X  Y
# 0    7  5
# 1    7  4
# 2    7  4
# 3    8  6
# 4    8  6
# ..  .. ..
# 512  4  3
# 513  2  4
# 514  7  4
# 515  1  4
# 516  6  3
#
# [517 rows x 2 columns]

# %%
df1=df[(df['area'] > 0.0) & (df['wind'] > 1.0) & (df['temp'] > 15.0)]
df1
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0   0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0   0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0   0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0   0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0   0.61
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 509  5  4   aug  fri  91.0  166.9  752.6   7.1  21.1  71   7.6   1.4   2.17
# 510  6  5   aug  fri  91.0  166.9  752.6   7.1  18.2  62   5.4   0.0   0.43
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
#
# [212 rows x 13 columns]

# %%
print(df.head())
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df['Awesome Place'] = (df['area'] > 0.0) & (df['wind'] > 1.0) & (df['temp'] > 15.0)
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
#      Awesome Place
# 0            False
# ...

# %%
df['Awesome Place'] = df['Awesome Place'].apply(lambda x : 'Yeah' if x==True else 'Nope')

# %%
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
#     Awesome Place
# 0            Nope
# ...

# %%
df[df['Awesome Place'] == 'Yeah']
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0   0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0   0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0   0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0   0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0   0.61
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 509  5  4   aug  fri  91.0  166.9  752.6   7.1  21.1  71   7.6   1.4   2.17
# 510  6  5   aug  fri  91.0  166.9  752.6   7.1  18.2  62   5.4   0.0   0.43
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
#
#     Awesome Place
# 138          Yeah
# ...

# %%
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv')
# print(df)
df['Training'] = df['Rating'].apply(lambda x : 'Yes' if x <= 3.5 else 'No')
print(df)
# Out:
#         ID Department     Office  Rating Training
# 0    U2F26    Finance  New Delhi     3.4      Yes
# 1    U2M61  Marketing  New Delhi     3.9       No
# 2    U1S15      Sales  New Delhi     2.8      Yes
# 3    U1H87         HR     Mumbai     2.1      Yes
# 4    U1S51      Sales  New Delhi     4.6       No
# ..     ...        ...        ...     ...      ...
# 528  U3S44      Sales  New Delhi     4.8       No
# 529  U2M11  Marketing  Bangalore     2.5      Yes
# 530  U3F53    Finance  Bangalore     3.2      Yes
# 531  U3S46      Sales  Bangalore     2.9      Yes
# 532  U3S28      Sales  New Delhi     2.9      Yes
#
# [533 rows x 5 columns]

# %%
dfgroup = df.groupby(['Department']).count()
dfgroup
type(dfgroup)
# Out:
# pandas.core.frame.DataFrame

# %%
for i in ['Finance', 'HR', 'Sales', 'Marketing']:
    print(i, len(df[(df['Training'] == 'Yes') & (df['Department'] == i)]) / len(df[df['Department'] == i]) * 100)
# Out:
# Finance 50.0
# HR 42.74809160305343
# Sales 50.76923076923077
# Marketing 53.62318840579711

# %%
type(df.groupby(df['Department']).mean().sort_values('Rating'))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16012\2577497670.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   type(df.groupby(df['Department']).mean().sort_values('Rating'))
# pandas.core.frame.DataFrame

# %%
dfx = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
# dfx_1=dfx.groupby(['rain','wind']).mean()
dfx_1=dfx.groupby(['rain','wind']).mean()
dfx_1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16012\3236292757.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfx_1=dfx.groupby(['rain','wind']).mean()
#                   X         Y       FFMC         DMC          DC        ISI  \
# rain wind
# 0.0  0.4   3.000000  4.000000  93.100000  157.300000  666.700000  13.500000
#      0.9   3.923077  3.769231  84.938462   85.876923  479.438462   7.607692
#      1.3   5.142857  4.428571  92.521429  124.457143  626.907143   9.850000
#      1.8   4.741935  4.290323  90.338710   97.796774  532.361290   7.751613
#      2.2   4.132075  4.283019  91.620755  128.052830  652.269811   7.858491
#      2.7   5.204545  4.409091  89.613636  110.990909  587.111364   7.754545
#      3.1   4.433962  4.433962  90.611321  109.643396  537.184906   8.139623
# ...

# %%
sales = pd.read_csv('junesales.csv', header=0)
print(sales.head())
# Out:
#        Date  Tea_sales(in 100's)
# 0  6/1/2011                   26
# 1  6/2/2011                   35
# 2  6/3/2011                   37
# 3  6/4/2011                   33
# 4  6/5/2011                   25

# %%
sales['Day'] = pd.DatetimeIndex(sales['Date']).day_of_week
print(sales.head())
daylist=[2,4,6]
# print(sales['Day'] in daylist)
selected=sales[(sales['Day'] == 3) & (sales['Tea_sales(in 100\'s)'] > 35)]
selected
# Out:
#        Date  Tea_sales(in 100's)  Day
# 0  6/1/2011                   26    2
# 1  6/2/2011                   35    3
# 2  6/3/2011                   37    4
# 3  6/4/2011                   33    5
# 4  6/5/2011                   25    6
#          Date  Tea_sales(in 100's)  Day
# 15  6/16/2011                   39    3
# 22  6/23/2011                   39    3
# 29  6/30/2011                   40    3

# %%
# dc = [index=['Day','DressCode'],[(1,'white'),(2,'green'),(3,'red')]]
cddf = pd.DataFrame([[1,'white'],[2,'green'],[3,'red']],columns=['Day','DressCode'])
cddf
# Out:
#    Day DressCode
# 0    1     white
# 1    2     green
# 2    3       red

# %%
merged = sales.merge(cddf, on ='Day', how='right')
print(merged)
# Out:
#          Date  Tea_sales(in 100's)  Day DressCode
# 0    6/7/2011                   43    1     white
# 1   6/14/2011                   25    1     white
# 2   6/21/2011                   48    1     white
# 3   6/28/2011                   46    1     white
# 4    6/1/2011                   26    2     green
# 5    6/8/2011                   33    2     green
# 6   6/15/2011                   28    2     green
# 7   6/22/2011                   23    2     green
# 8   6/29/2011                   48    2     green
# 9    6/2/2011                   35    3       red
# 10   6/9/2011                   28    3       red
# 11  6/16/2011                   39    3       red
# 12  6/23/2011                   39    3       red
# 13  6/30/2011                   40    3       red

# %%
cddf1 = pd.DataFrame([[4,'Purple'],[5,'Maroon'],[6,'Orange']],columns=['Day','DressCode'])
cddf1
# Out:
#    Day DressCode
# 0    4    Purple
# 1    5    Maroon
# 2    6    Orange

# %%
# con = pd.concat([cddf,cddf1], axis=1)
con = pd.concat([cddf,cddf1], axis=0)
con
# Out:
#    Day DressCode
# 0    1     white
# 1    2     green
# 2    3       red
# 0    4    Purple
# 1    5    Maroon
# 2    6    Orange

# %%
import warnings
warnings.simplefilter("ignore")

import pandas as pd
df_1 = pd.read_csv('https://cdn.upgrad.com/uploads/production/1ed2840b-f083-44fe-9eb4-acda009ac620/restaurant-1.csv')
df_2 = pd.read_csv('https://cdn.upgrad.com/uploads/production/c87b99b4-467c-4128-8729-85bff0b0acbe/restaurant-2.csv')
df_3 = pd.concat([df_1,df_2],axis=0)

df_3
# Out:
#                           name                     address             city  \
# 0    arnie morton's of chicago   "435 s. la cienega blvd."    "los angeles"
# 1                   art's deli       "12224 ventura blvd."    "studio city"
# 2                bel-air hotel      "701 stone canyon rd."        "bel air"
# 3                   cafe bizou       "14016 ventura blvd."   "sherman oaks"
# 4                    campanile       "624 s. la brea ave."    "los angeles"
# ..                         ...                         ...              ...
# 747                        NaN                         NaN              NaN
# 748                        NaN                         NaN              NaN
# 749                        NaN                         NaN              NaN
# 750                        NaN                         NaN              NaN
# 751                        NaN                         NaN              NaN
#
# ...

# %%
# pvt = merged.pivot_table(index='DressCode',columns='Tea_sales(in 100\'s)',values='Day',aggfunc='mean')
pvt = merged.pivot_table(index='DressCode',columns='Tea_sales(in 100\'s)',values='Day')

# %%
pvt
# Out:
# Tea_sales(in 100's)   23   25   26   28   33   35   39   40   43   46   48
# DressCode
# green                2.0  NaN  2.0  2.0  2.0  NaN  NaN  NaN  NaN  NaN  2.0
# red                  NaN  NaN  NaN  3.0  NaN  3.0  3.0  3.0  NaN  NaN  NaN
# white                NaN  1.0  NaN  NaN  NaN  NaN  NaN  NaN  1.0  1.0  1.0

# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
marks = pd.read_csv('https://query.data.world/s/HqjNNadqEnwSq1qnoV_JqyRJkc7o6O')
marks.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
marks.isnull().sum()
# Out:
# Prefix         0
# Assignment     2
# Tutorial      12
# Midterm       16
# TakeHome       9
# Final          5
# dtype: int64

# %%
marks.columns[marks.isnull().sum()==5][0]
# Out:
# 'Final'

# %%
print(marks)
# marks.isnull().sum()
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
# marks.drop('Final', axis=0, inplace=True)
marks.info()
marks = marks.drop('Final', axis=1)
marks.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  97 non-null     float64
#  2   Tutorial    87 non-null     float64
#  3   Midterm     83 non-null     float64
#  4   TakeHome    90 non-null     float64
#  5   Final       94 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB
#    Prefix  Assignment  Tutorial  Midterm  TakeHome
# 0       5       57.14     34.09    64.38     51.48
# 1       8       95.05    105.49    67.50     99.07
# 2       8       83.70     83.17    30.00     63.15
# 3       7       81.22     96.06    49.38    105.93
# 4       8       91.32     93.64    95.00    107.41

# %%
null_counts = marks.isnull().sum(axis=1)
print(null_counts.value_counts())
# Out:
# 0    79
# 1     8
# 3     6
# 2     4
# 5     2
# dtype: int64

# %%
marks.isnull().sum()
# Out:
# Prefix         0
# Assignment     0
# Tutorial      10
# Midterm       14
# TakeHome       7
# Final          3
# dtype: int64

# %%
marks.drop(null_counts[null_counts >= 5].index, inplace=True)

# %%
customer = pd.read_csv('https://query.data.world/s/y9rxL9mGdP6AXPiDaIL4yYm6DsfTV2')

# customer['Cust_id'] =#Type your code here
print(customer.head(10))
# Out:
#         Customer_Name Province   Region Customer_Segment  Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS   Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER   Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE   Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER   Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE   Cust_5
# 5      MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE   Cust_6
# 6     DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE   Cust_7
# 7     NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE   Cust_8
# 8         CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE   Cust_9
# 9       CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_10

# %%
customer.Cust_id = customer['Cust_id'].apply(lambda x : x.replace('Cust_',''))
customer.head(10)
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS       1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER       2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE       3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER       4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE       5
# 5      MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE       6
# 6     DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE       7
# 7     NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE       8
# 8         CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE       9
# 9       CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS      10

# %%
import pandas as pd
rating = pd.read_csv('https://query.data.world/s/EX0EpmqwfA2UYGz1Xtd_zi4R0dQpog')
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userID          1254 non-null   object
#  1   placeID         1254 non-null   int64
#  2   rating          1254 non-null   int64
#  3   food_rating     1254 non-null   int64
#  4   service_rating  1254 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 49.1+ KB

# %%
rating_update=rating.drop_duplicates()
# Out:
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 2     U1077   132825       2            2               2
# 3     U1077   135060       1            2               2
# 4     U1068   135104       1            1               2
# ...     ...      ...     ...          ...             ...
# 1249  U1043   132630       1            1               1
# 1250  U1011   132715       1            1               0
# 1251  U1068   132733       1            1               0
# 1252  U1068   132594       1            1               1
# 1253  U1068   132660       0            0               0
#
# [1149 rows x 5 columns]
