# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xldf = pd.read_excel('census+data.xlsx', skiprows=2)
xldf.info()
# xldf.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3136 entries, 0 to 3135
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Name                              3132 non-null   object
#  1   Code                              3132 non-null   float64
#  2   Code.1                            3132 non-null   float64
#  3   Unnamed: 3                        3132 non-null   object
#  4   Rural/                            3133 non-null   object
#  5   Unnamed: 5                        3133 non-null   object
#  6   Unnamed: 6                        3134 non-null   object
#  7   Unnamed: 7                        3134 non-null   object
#  8   Unnamed: 8                        3134 non-null   object
#  9   Unnamed: 9                        3134 non-null   object
#  10  Unnamed: 10                       3134 non-null   object
# ...

# %%
sdf=pd.read_csv('tendulkar_ODI.csv')
sdf.head(10)
# Out:
#    Unnamed: 0 Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0           1    0    -   2  0  0       0   5    caught    2     v Pakistan
# 1           2    0    2   2  0  0       0   5    caught    2  v New Zealand
# 2           3   36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3           4   19   38  35  1  1   54.28   4    bowled    2      v England
# 4           5   31   31  26  3  0  119.23   6    bowled    2      v England
# 5           6   36    -  22  3  2  163.63   5    bowled    1    v Sri Lanka
# 6           7   53    -  41  7  1  129.26   5    bowled    2    v Sri Lanka
# 7           8   30    -  29  1  2  103.44   5    caught    1    v Sri Lanka
# 8           9  DNB    -   -  -  -       -   -         -    2   v Bangladesh
# 9          10    4    -  11  0  0   36.36   5       lbw    2    v Sri Lanka
#
#        Ground Start Date
# 0  Gujranwala  18-Dec-89
# 1     Dunedin   1-Mar-90
# 2  Wellington   6-Mar-90
# 3       Leeds  18-Jul-90
# ...

# %%
sdf.Runs.value_counts()
sdf.Runs=sdf.Runs.apply(lambda x: x.replace('*',''))

# %%
sdf.Runs.value_counts()
sdf.Runs.value_counts().plot()
# Out:
# 1      16
# 2      14
# 0      12
# 4       9
# 21      8
#        ..
# 81      1
# 89      1
# 102     1
# 86      1
# 85      1
# Name: Runs, Length: 107, dtype: int64

# %%
sdf['4s'].hist()
# Out:
# <Axes: >

# %%
pdf=pd.read_csv('popularity.csv')
# pdf.head(10)
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1    timedelta                      39644 non-null  float64
#  2    n_tokens_title                 39644 non-null  float64
#  3    n_tokens_content               39644 non-null  float64
#  4    n_unique_tokens                39644 non-null  float64
#  5    n_non_stop_words               39644 non-null  float64
#  6    n_non_stop_unique_tokens       39644 non-null  float64
#  7    num_hrefs                      39644 non-null  float64
#  8    num_self_hrefs                 39644 non-null  float64
#  9    num_imgs                       39644 non-null  float64
#  10   num_videos                     39644 non-null  float64
#  11   average_token_length           39644 non-null  float64
# ...

# %%
# pdf[' num_keywords'].head()
pdf[' shares'].value_counts()
# pdf[' num_imgs'].value_count()
# pdf[' num_keywords']
# pdf['url']
pdf[' shares'].median()
# Out:
# 1400.0

# %% [markdown]
# # graded

# %%
pdf.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# ...

# %%
pdf[' shares'].quantile(.78)
# Out:
# 3100.0

# %%
pdf[' shares'].plot()
# Out:
# <Axes: >

# %%
pdf[pdf[' shares'] < pdf[' shares'].quantile(0.95)][' shares'].value_counts()
# Out:
# 1100    2308
# 1200    2018
# 1300    1740
# 1400    1592
# 1500    1323
#         ...
# 130        1
# 236        1
# 192        1
# 223        1
# 76         1
# Name:  shares, Length: 953, dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=[10,8])
sns.boxplot(pdf[' shares'])
# Out:
# <Axes: >

# %%
pdf[' shares'].plot()
# Out:
# <Axes: >

# %%
# pdf = pdf[pdf[' shares'] < (2800-964)*1.5]
pdf.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# ...

# %%
pdf[pdf[' shares'] < 10800].describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  37644.000000     37644.000000       37644.000000      37644.000000
# mean     354.182021        10.395043         547.980555          0.549133
# std      214.850004         2.112189         467.292281          3.612836
# min        8.000000         2.000000           0.000000          0.000000
# 25%      163.000000         9.000000         248.000000          0.470792
# 50%      338.000000        10.000000         413.000000          0.538695
# 75%      545.000000        12.000000         718.000000          0.607477
# max      731.000000        23.000000        7764.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       37644.000000               37644.000000  37644.000000
# mean            0.998884                   0.690785     10.744740
# std             5.368161                   3.350150     11.125541
# ...

# %%
dfe = pd.read_csv('EDA_nas.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STUID                   8801 non-null   int64
#  1   State                   8801 non-null   object
#  2   District                8801 non-null   int64
#  3   Gender                  8799 non-null   object
#  4   Age                     8569 non-null   object
#  5   Category                8232 non-null   float64
#  6   Same.language           8572 non-null   float64
#  7   Siblings                8801 non-null   object
#  8   Handicap                8304 non-null   object
#  9   Father.edu              8147 non-null   object
#  10  Mother.edu              7950 non-null   object
#  11  Father.occupation       7761 non-null   object
#  12  Mother.occupation       6626 non-null   object
#  13  Below.poverty           7347 non-null   object
# ...

# %%
# print(dfe.columns)
import pandas as pd
dfe = pd.read_csv('EDA_nas.csv')
print(dfe.iloc[:,-3:])
# Out:
#       Reading..  Science..  Social..
# 0         33.33        NaN       NaN
# 1         62.07        NaN       NaN
# 2         41.38        NaN       NaN
# 3           NaN        NaN       NaN
# 4           NaN      27.27       NaN
# ...         ...        ...       ...
# 8796        NaN      34.55     30.61
# 8797      46.67        NaN       NaN
# 8798      55.17        NaN       NaN
# 8799        NaN      23.64     34.69
# 8800        NaN      27.27     30.61
#
# [8801 rows x 3 columns]

# %%
dfc = pd.read_excel('EDA_census.xlsx', usecols='F,G,M', skiprows=7)
# df = pd.read_excel('player_data.xlsx', usecols='A:C, D')
dfc
# Out:
#             All ages  1210854977  763638812
# 0                0-6   164515253          0
# 1                  7    24826640   18078426
# 2                  8    26968373   22836959
# 3                  9    23424638   20932734
# 4                 10    30552107   27097602
# ...              ...         ...        ...
# 3126           65-69        1757       1171
# 3127           70-74        1193        774
# 3128           75-79         645        411
# 3129             80+         616        352
# 3130  Age not stated         188        152
#
# [3131 rows x 3 columns]

# %%
dfc1 = dfc.iloc[1:27]
dfc1.columns=['Age','total','literate']
dfc1
dfc1['perc'] = (dfc1['literate'] / dfc1['total']) * 100
dfc1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1036\3052886634.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc1['perc'] = (dfc1['literate'] / dfc1['total']) * 100
#       Age      total  literate       perc
# 1       7   24826640  18078426  72.818658
# 2       8   26968373  22836959  84.680522
# 3       9   23424638  20932734  89.362038
# 4      10   30552107  27097602  88.693071
# 5      11   24740946  22752473  91.962826
# 6      12   27877307  25485778  91.421234
# 7      13   24280683  22470207  92.543554
# 8      14   25258169  23157384  91.682750
# 9      15   25899454  23299497  89.961344
# 10     16   24592293  22079806  89.783437
# 11     17   21217467  19179012  90.392562
# 12     18   27958147  24230172  86.665872
# ...

# %%
dfcall= pd.read_excel('EDA_census.xlsx', skiprows=6, usecols='D,O')
dfcall.columns=['Area','femlit']
dfcall
# Out:
#                                    Area     femlit
# 0                                 INDIA  328875190
# 1                                 INDIA          0
# 2                                 INDIA    8563745
# 3                                 INDIA   10788764
# 4                                 INDIA    9916088
# ...                                 ...        ...
# 3127  State - ANDAMAN & NICOBAR ISLANDS        413
# 3128  State - ANDAMAN & NICOBAR ISLANDS        223
# 3129  State - ANDAMAN & NICOBAR ISLANDS        148
# 3130  State - ANDAMAN & NICOBAR ISLANDS        133
# 3131  State - ANDAMAN & NICOBAR ISLANDS         69
#
# [3132 rows x 2 columns]

# %%
dfcall = dfcall.loc[dfcall['Area'] != 'INDIA']
plt.figure(figsize=[30,7])
# plt.plot(dfcall.groupby('Area').mean())
dfcall.groupby('Area').mean().plot.bar() #-------This is wrong, need to take ratio not count.
# Out:
# <Axes: xlabel='Area'>
